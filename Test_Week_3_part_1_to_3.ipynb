# %% [markdown]
# # Test Week 3 First Part

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
html_data = requests.get(url).text
soup = BeautifulSoup(html_data, "lxml")

table_contents = []
table = soup.find("table")
for row in table.findAll("td"):
    cell = {}
    if row.span.text == "Not assigned":
        pass
    else:
        cell["CódigoPostal"] = row.p.text[:3]
        cell["Municipio"] = (row.span.text).split("(")[0]
        cell["Vecindario"] = (((((row.span.text).split("(")[1]).strip(")")).replace(" /", ",")).replace(")", " ")).strip(" ")
        table_contents.append(cell)

df = pd.DataFrame(table_contents)
df["Municipio"] = df["Municipio"].replace({"Downtown TorontoStn A PO Boxes25 The Esplanade": "Downtown Toronto Stn A",
                                           "East TorontoBusiness reply mail Processing Centre969 Eastern": "East Toronto Business",
                                           "EtobicokeNorthwest": "Etobicoke Northwest",
                                           "East YorkEast Toronto": "East York/East Toronto",
                                           "MississaugaCanada Post Gateway Processing Centre": "Mississauga"})

print(df)

# Imprimir el número de filas del marco de datos
print("\nNúmero de filas en el marco de datos: ", df.shape[0])
# Out:
#     CódigoPostal              Municipio  \
# 0            M3A             North York
# 1            M4A             North York
# 2            M5A       Downtown Toronto
# 3            M6A             North York
# 4            M7A           Queen's Park
# ..           ...                    ...
# 98           M8X              Etobicoke
# 99           M4Y       Downtown Toronto
# 100          M7Y  East Toronto Business
# 101          M8Y              Etobicoke
# 102          M8Z              Etobicoke
#
#                                             Vecindario
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                            Regent Park, Harbourfront
# 3                     Lawrence Manor, Lawrence Heights
# 4                        Ontario Provincial Government
# ..                                                 ...
# 98       The Kingsway, Montgomery Road, Old Mill North
# 99                                Church and Wellesley
# 100                                     Enclave of M4L
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 102  Mimico NW, The Queensway West, South of Bloor,...
#
# [103 rows x 3 columns]
#
# Número de filas en el marco de datos:  103

# %% [markdown]
# # Test Week 3 Second Part

# %%
import pandas as pd

# Cargar el archivo CSV de coordenadas
coordinates_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/labs_v1/Geospatial_Coordinates.csv"
coordinates_df = pd.read_csv(coordinates_url)

# Renombrar la columna 'Postal Code' a 'CódigoPostal'
coordinates_df.rename(columns={"Postal Code": "CódigoPostal"}, inplace=True)

# Combinar el DataFrame original 'df' con el DataFrame de coordenadas 'coordinates_df' usando la columna 'CódigoPostal'
df_with_coordinates = pd.merge(df, coordinates_df, on="CódigoPostal")

print(df_with_coordinates)
# Out:
#     CódigoPostal              Municipio  \
# 0            M3A             North York
# 1            M4A             North York
# 2            M5A       Downtown Toronto
# 3            M6A             North York
# 4            M7A           Queen's Park
# ..           ...                    ...
# 98           M8X              Etobicoke
# 99           M4Y       Downtown Toronto
# 100          M7Y  East Toronto Business
# 101          M8Y              Etobicoke
# 102          M8Z              Etobicoke
#
#                                             Vecindario   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                            Regent Park, Harbourfront  43.654260 -79.360636
# 3                     Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4                        Ontario Provincial Government  43.662301 -79.389494
# ..                                                 ...        ...        ...
# 98       The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 99                                Church and Wellesley  43.665860 -79.383160
# 100                                     Enclave of M4L  43.662744 -79.321558
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...  43.636258 -79.498509
# 102  Mimico NW, The Queensway West, South of Bloor,...  43.628841 -79.520999
#
# [103 rows x 5 columns]

# %% [markdown]
# # Test Week 3 Third Part

# %%
import folium
import requests
from sklearn.cluster import KMeans
import numpy as np
import matplotlib.cm as cm
import matplotlib.colors as colors

# Filtrar los municipios que contienen la palabra 'Toronto'
toronto_data = df_with_coordinates[df_with_coordinates['Municipio'].str.contains('Toronto')].reset_index(drop=True)

# Coordenadas de Toronto
latitude = 43.6532
longitude = -79.3832

# Crear mapa de Toronto con los vecindarios marcados
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=12)

for lat, lng, label in zip(toronto_data['Latitude'], toronto_data['Longitude'], toronto_data['Vecindario']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  

# Mostrar mapa
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS = false; L_NO_TOUCH = false; L_DISABLE_3D = false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#             &lt;style&gt; #map_d85aad99a51d34e078f70931609dc4c7 {
#                 position : relative;
#                 width : 100.0%;
#                 height: 100.0%;
#                 left: 0.0%;
#                 top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d85aad99a51d34e078f70931609dc4c7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#
#
#                 var bounds = null;
#
#
#             var map_d85aad99a51d34e078f70931609dc4c7 = L.map(
#                                   &#x27;map_d85aad99a51d34e078f70931609dc4c7&#x27;,
#                                   {center: [43.6532,-79.3832],
#                                   zoom: 12,
#                                   maxBounds: bounds,
#                                   layers: [],
#                                   worldCopyJump: false,
#                                   crs: L.CRS.EPSG3857
#                                  });
#
#
#
#             var tile_layer_c5ad812c8ae77ac1b399823fa365c322 = L.tileLayer(
#                 &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#                 {
#   &quot;attribution&quot;: null,
#   &quot;detectRetina&quot;: false,
#   &quot;maxZoom&quot;: 18,
#   &quot;minZoom&quot;: 1,
#   &quot;noWrap&quot;: false,
#   &quot;subdomains&quot;: &quot;abc&quot;
# }
#                 ).addTo(map_d85aad99a51d34e078f70931609dc4c7);
#
#
#             var circle_marker_bc008c8bdec5eaf3119a1c72947f330a = L.circleMarker(
#                 [43.6542599,-79.3606359],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;blue&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3186cc&quot;,
#   &quot;fillOpacity&quot;: 0.7,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 5,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 ).addTo(map_d85aad99a51d34e078f70931609dc4c7);
#
#
#             var popup_56b1e62829c9b56425d7d655ff03f57e = L.popup({maxWidth: &#x27;300&#x27;});
#
#
#                 var html_e94f0f3e84a4b6d46f91ce7ad0b88213 = $(&#x27;&lt;div id=&quot;html_e94f0f3e84a4b6d46f91ce7ad0b88213&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Regent Park, Harbourfront&lt;/div&gt;&#x27;)[0];
#                 popup_56b1e62829c9b56425d7d655ff03f57e.setContent(html_e94f0f3e84a4b6d46f91ce7ad0b88213);
#
#
#             circle_marker_bc008c8bdec5eaf3119a1c72947f330a.bindPopup(popup_56b1e62829c9b56425d7d655ff03f57e);
#
#
#
#
#             var circle_marker_402d00585bfd1c685b729ada4251c725 = L.circleMarker(
#                 [43.6571618,-79.3789371],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;blue&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3186cc&quot;,
#   &quot;fillOpacity&quot;: 0.7,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 5,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 ).addTo(map_d85aad99a51d34e078f70931609dc4c7);
#
#
#             var popup_76f343ec5ef51c0b73df932f5b12606b = L.popup({maxWidth: &#x27;300&#x27;});
#
#
#                 var html_93d20d041201901cd28e4cc34be4246d = $(&#x27;&lt;div id=&quot;html_93d20d041201901cd28e4cc34be4246d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Garden District, Ryerson&lt;/div&gt;&#x27;)[0];
#                 popup_76f343ec5ef51c0b73df932f5b12606b.setContent(html_93d20d041201901cd28e4cc34be4246d);
#
#
#             circle_marker_402d00585bfd1c685b729ada4251c725.bindPopup(popup_76f343ec5ef51c0b73df932f5b12606b);
#
#
#
#
#             var circle_marker_dc35dd368f32b9dcf4ba5437df4570de = L.circleMarker(
#                 [43.6514939,-79.3754179],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;blue&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3186cc&quot;,
#   &quot;fillOpacity&quot;: 0.7,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 5,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 ).addTo(map_d85aad99a51d34e078f70931609dc4c7);
#
#
#             var popup_26193f1d7e223437d00a7bf5cc089dfc = L.popup({maxWidth: &#x27;300&#x27;});
#
#
#                 var html_90f4b488dca48796313ee136a4b1bb68 = $(&#x27;&lt;div id=&quot;html_90f4b488dca48796313ee136a4b1bb68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;St. James Town&lt;/div&gt;&#x27;)[0];
#                 popup_26193f1d7e223437d00a7bf5cc089dfc.setContent(html_90f4b488dca48796313ee136a4b1bb68);
#
#
#             circle_marker_dc35dd368f32b9dcf4ba5437df4570de.bindPopup(popup_26193f1d7e223437d00a7bf5cc089dfc);
#
#
#
#
#             var circle_marker_0007fef9cd82a0b487c8d825ec8d751a = L.circleMarker(
#                 [43.6763574,-79.2930312],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;blue&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3186cc&quot;,
#   &quot;fillOpacity&quot;: 0.7,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 5,
#   &quot;stroke&quot;: true,
#   &quot;w

# %%
# Cantidad de agrupaciones
k = 5

toronto_grouped_clustering = toronto_data.drop(['CódigoPostal', 'Municipio', 'Vecindario'], axis=1)


# Ejecutar KMeans
kmeans = KMeans(n_clusters=k, random_state=0).fit(toronto_grouped_clustering)

# Agregar las etiquetas de agrupamiento al DataFrame
toronto_data.insert(0, 'EtiquetaAgrupamiento', kmeans.labels_)

# Función para obtener colores
def get_color(n, max_n):
    norm = colors.Normalize(vmin=0, vmax=max_n)
    cmap = cm.get_cmap("viridis")
    return cmap(norm(n))

# Crear mapa de agrupaciones de vecindarios
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=12)

for lat, lng, label, cluster in zip(toronto_data['Latitude'], toronto_data['Longitude'], toronto_data['Vecindario'], toronto_data['EtiquetaAgrupamiento']):
    label = folium.Popup(f"Cluster {cluster}: {label}", parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color=get_color(cluster, k),
        fill=True,
        fill_color=get_color(cluster, k),
        fill_opacity=0.7,
        parse_html=False).add_to(map_clusters)

# Mostrar mapa de agrupaciones
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS = false; L_NO_TOUCH = false; L_DISABLE_3D = false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#             &lt;style&gt; #map_b97d733213337e447d17b19c700a2a8d {
#                 position : relative;
#                 width : 100.0%;
#                 height: 100.0%;
#                 left: 0.0%;
#                 top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b97d733213337e447d17b19c700a2a8d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#
#
#                 var bounds = null;
#
#
#             var map_b97d733213337e447d17b19c700a2a8d = L.map(
#                                   &#x27;map_b97d733213337e447d17b19c700a2a8d&#x27;,
#                                   {center: [43.6532,-79.3832],
#                                   zoom: 12,
#                                   maxBounds: bounds,
#                                   layers: [],
#                                   worldCopyJump: false,
#                                   crs: L.CRS.EPSG3857
#                                  });
#
#
#
#             var tile_layer_3ce163fcd6155a45bafc93218f31d3b8 = L.tileLayer(
#                 &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#                 {
#   &quot;attribution&quot;: null,
#   &quot;detectRetina&quot;: false,
#   &quot;maxZoom&quot;: 18,
#   &quot;minZoom&quot;: 1,
#   &quot;noWrap&quot;: false,
#   &quot;subdomains&quot;: &quot;abc&quot;
# }
#                 ).addTo(map_b97d733213337e447d17b19c700a2a8d);
#
#
#             var circle_marker_b91b49f99084f6b93c034efaa9244bee = L.circleMarker(
#                 [43.6542599,-79.3606359],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: [
#     0.477504,
#     0.821444,
#     0.318195,
#     1.0
#   ],
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: [
#     0.477504,
#     0.821444,
#     0.318195,
#     1.0
#   ],
#   &quot;fillOpacity&quot;: 0.7,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 5,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 ).addTo(map_b97d733213337e447d17b19c700a2a8d);
#
#
#             var popup_000f5e6d5624627c0241a952dc152270 = L.popup({maxWidth: &#x27;300&#x27;});
#
#
#                 var html_6b79be9563f2be1a91be62013ad087f1 = $(&#x27;&lt;div id=&quot;html_6b79be9563f2be1a91be62013ad087f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 4: Regent Park, Harbourfront&lt;/div&gt;&#x27;)[0];
#                 popup_000f5e6d5624627c0241a952dc152270.setContent(html_6b79be9563f2be1a91be62013ad087f1);
#
#
#             circle_marker_b91b49f99084f6b93c034efaa9244bee.bindPopup(popup_000f5e6d5624627c0241a952dc152270);
#
#
#
#
#             var circle_marker_15f7ed88e7f66e0dc19fa8bc63caab06 = L.circleMarker(
#                 [43.6571618,-79.3789371],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: [
#     0.477504,
#     0.821444,
#     0.318195,
#     1.0
#   ],
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: [
#     0.477504,
#     0.821444,
#     0.318195,
#     1.0
#   ],
#   &quot;fillOpacity&quot;: 0.7,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 5,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 ).addTo(map_b97d733213337e447d17b19c700a2a8d);
#
#
#             var popup_276a25639a99f114c198e33a8d6dbdde = L.popup({maxWidth: &#x27;300&#x27;});
#
#
#                 var html_7ea9c1200cfc7507a18b27292fc46226 = $(&#x27;&lt;div id=&quot;html_7ea9c1200cfc7507a18b27292fc46226&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 4: Garden District, Ryerson&lt;/div&gt;&#x27;)[0];
#                 popup_276a25639a99f114c198e33a8d6dbdde.setContent(html_7ea9c1200cfc7507a18b27292fc46226);
#
#
#             circle_marker_15f7ed88e7f66e0dc19fa8bc63caab06.bindPopup(popup_276a25639a99f114c198e33a8d6dbdde);
#
#
#
#
#             var circle_marker_8b5fd5800cadbd807abbf148657d768b = L.circleMarker(
#                 [43.6514939,-79.3754179],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: [
#     0.477504,
#     0.821444,
#     0.318195,
#     1.0
#   ],
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: [
#     0.477504,
#     0.821444,
#     0.318195,
#     1.0
#   ],
#   &quot;fillOpacity&quot;: 0.7,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 5,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 ).addTo(map_b97d733213337e447d17b19c700a2a8d);
#
#
#             var popup_5b78fe41ed66ef0087a94f021632f886 = L.popup({maxWidth: &#x27;300&#x27;});
#
#
#                 var html_548ed021375baecef7ed77101e5c812b = $(&#x27;&lt;div id=&quot;html_548ed021375baecef7ed77101e5c812b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 4: St. James Town&lt;/div&gt;&#x27;)[0];
#                 popup_5b78fe41ed66ef0087a94f021632f886.setContent(html_548ed021375baecef7ed77101e5c812b);
#
#
#             circle_marker_8b5fd5800cadbd807abbf148657d768b.bindPopup(popup_5b78fe41ed66ef0087a94f021632f886);
#
#
#
#
#             var circle_marker_ecc31eadcee07a5f087fb703152c3bbe = L.circleMarker(
#                 [43.6763574,-79.2930312],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: [
#     0.253935,
#     0.265254,
#     0.529983,
#     1.0
#   ],
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
